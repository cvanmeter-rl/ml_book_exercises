# %%
import numpy as np
from matplotlib.pyplot import subplots
import pandas as pd
# 8 (a)
df_c = pd.read_csv('College.csv')
df_c
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 0           52         2885          537      7440        3300    450
# 1           29         2683         1227     12280        6450    750
# 2           50         1036           99     11250        3750    400
# 3           89          510           63     12960        5450    450
# 4           44          249          869      7560        4120    800
# ..         ...          ...          ...       ...         ...    ...
# 772         26         3089         2029      6797        3900    500
# 773         47         2849         1107     11520        4960    600
# 774         61         2793          166      6900        4200    617
# 775         99         5217           83     19840        6510    630
# 776         63         2988         1726      4990        3560    500
#
#      Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0        2200   70        78       18.1           12    7041         60
# 1        1500   29        30       12.2           16   10527         56
# 2        1165   53        66       12.9           30    8735         54
# 3         875   92        97        7.7           37   19016         59
# 4        1500   76        72       11.9            2   10922         15
# ..        ...  ...       ...        ...          ...     ...        ...
# 772      1200   60        60       21.0           14    4469         40
# 773      1250   73        75       13.3           31    9189         83
# 774       781   67        75       14.4           20    8323         49
# 775      2115   96        96        5.8           49   40386         99
# 776      1250   75        75       18.1           28    4509         99
#
# [777 rows x 19 columns]

# %%
# 8 (b)
college = df_c.set_index(['Unnamed: 0'],append=True, verify_integrity=True)
college.rename_axis([None,'College'],inplace=True)
college
# Out:
#                                    Private   Apps  Accept  Enroll  Top10perc  \
#     College
# 0   Abilene Christian University       Yes   1660    1232     721         23
# 1   Adelphi University                 Yes   2186    1924     512         16
# 2   Adrian College                     Yes   1428    1097     336         22
# 3   Agnes Scott College                Yes    417     349     137         60
# 4   Alaska Pacific University          Yes    193     146      55         16
# ...                                    ...    ...     ...     ...        ...
# 772 Worcester State College             No   2197    1515     543          4
# 773 Xavier University                  Yes   1959    1805     695         24
# 774 Xavier University of Louisiana     Yes   2097    1915     695         34
# 775 Yale University                    Yes  10705    2453    1317         95
# 776 York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                     Top25perc  F.Undergrad  P.Undergrad  \
#     College
# 0   Abilene Christian University           52         2885          537
# 1   Adelphi University                     29         2683         1227
# 2   Adrian College                         50         1036           99
# 3   Agnes Scott College                    89          510           63
# 4   Alaska Pacific University              44          249          869
# ...                                       ...          ...          ...
# 772 Worcester State College                26         3089         2029
# 773 Xavier University                      47         2849         1107
# 774 Xavier University of Louisiana         61         2793          166
# 775 Yale University                        99         5217           83
# 776 York College of Pennsylvania           63         2988         1726
#
#                                     Outstate  Room.Board  Books  Personal  \
#     College
# 0   Abilene Christian University        7440        3300    450      2200
# 1   Adelphi University                 12280        6450    750      1500
# 2   Adrian College                     11250        3750    400      1165
# 3   Agnes Scott College                12960        5450    450       875
# 4   Alaska Pacific University           7560        4120    800      1500
# ...                                      ...         ...    ...       ...
# 772 Worcester State College             6797        3900    500      1200
# 773 Xavier University                  11520        4960    600      1250
# 774 Xavier University of Louisiana      6900        4200    617       781
# 775 Yale University                    19840        6510    630      2115
# 776 York College of Pennsylvania        4990        3560    500      1250
#
#                                     PhD  Terminal  S.F.Ratio  perc.alumni  \
#     College
# 0   Abilene Christian University     70        78       18.1           12
# 1   Adelphi University               29        30       12.2           16
# 2   Adrian College                   53        66       12.9           30
# 3   Agnes Scott College              92        97        7.7           37
# 4   Alaska Pacific University        76        72       11.9            2
# ...                                 ...       ...        ...          ...
# 772 Worcester State College          60        60       21.0           14
# 773 Xavier University                73        75       13.3           31
# 774 Xavier University of Louisiana   67        75       14.4           20
# 775 Yale University                  96        96        5.8           49
# 776 York College of Pennsylvania     75        75       18.1           28
#
#                                     Expend  Grad.Rate
#     College
# 0   Abilene Christian University      7041         60
# 1   Adelphi University               10527         56
# 2   Adrian College                    8735         54
# 3   Agnes Scott College              19016         59
# 4   Alaska Pacific University        10922         15
# ...                                    ...        ...
# 772 Worcester State College           4469         40
# 773 Xavier University                 9189         83
# 774 Xavier University of Louisiana    8323         49
# 775 Yale University                  40386         99
# 776 York College of Pennsylvania      4509         99
#
# [777 rows x 18 columns]

# %%
#8 (c)
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# min      139.000000      1.000000   2340.000000  1780.000000    96.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   470.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#           Personal         PhD    Terminal   S.F.Ratio  perc.alumni  \
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean   1340.642214   72.660232   79.702703   14.089704    22.743887
# std     677.071454   16.328155   14.722359    3.958349    12.391801
# min     250.000000    8.000000   24.000000    2.500000     0.000000
# 25%     850.000000   62.000000   71.000000   11.500000    13.000000
# 50%    1200.000000   75.000000   82.000000   13.600000    21.000000
# 75%    1700.000000   85.000000   92.000000   16.500000    31.000000
# max    6800.000000  103.000000  100.000000   39.800000    64.000000
#
#              Expend  Grad.Rate
# count    777.000000  777.00000
# mean    9660.171171   65.46332
# std     5221.768440   17.17771
# min     3186.000000   10.00000
# 25%     6751.000000   53.00000
# 50%     8377.000000   65.00000
# 75%    10830.000000   78.00000
# max    56233.000000  118.00000

# %%
#8 (d)
pd.plotting.scatter_matrix(college[['Top10perc','Apps','Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
#8 (e)
college.boxplot(by='Private',column=['Outstate'],grid=False)
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
#8 (f)
college['Elite'] = college['Top10perc'] > 50
college['Elite']
# Out:
#      College
# 0    Abilene Christian University      False
# 1    Adelphi University                False
# 2    Adrian College                    False
# 3    Agnes Scott College                True
# 4    Alaska Pacific University         False
#                                        ...
# 772  Worcester State College           False
# 773  Xavier University                 False
# 774  Xavier University of Louisiana    False
# 775  Yale University                    True
# 776  York College of Pennsylvania      False
# Name: Elite, Length: 777, dtype: bool

# %%
college['Elite'].sum()
# Out:
# 78

# %%
#9 (a)
auto = pd.read_csv('Auto.csv',na_values=['?'])
auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#this drops the missing values which are stored as ? in this dataset
auto = auto.dropna()
auto.shape
# Out:
# (392, 9)

# %%
datatypes = {'quant': ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration'],
             'qual': ['origin', 'name']}
auto_quant = auto[datatypes['quant']].astype(np.float_)
auto_quant
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration
# 0    18.0        8.0         307.0       130.0  3504.0          12.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5
# 2    18.0        8.0         318.0       150.0  3436.0          11.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0        4.0         140.0        86.0  2790.0          15.6
# 393  44.0        4.0          97.0        52.0  2130.0          24.6
# 394  32.0        4.0         135.0        84.0  2295.0          11.6
# 395  28.0        4.0         120.0        79.0  2625.0          18.6
# 396  31.0        4.0         119.0        82.0  2720.0          19.4
#
# [392 rows x 6 columns]

# %%
#9 (b) and (c)
pd.DataFrame({'range':auto_quant.max() - auto_quant.min(),
              'mean':auto_quant.mean(),
              'std':auto_quant.std()
             })
# Out:
#                range         mean         std
# mpg             37.6    23.445918    7.805007
# cylinders        5.0     5.471939    1.705783
# displacement   387.0   194.411990  104.644004
# horsepower     184.0   104.469388   38.491160
# weight        3527.0  2977.584184  849.402560
# acceleration    16.8    15.541327    2.758864

# %%
# 9 (d) Now remove the 10th through 85th observations. 
# What is the range, mean, and standard deviation of each predictor 
# in the subset of the data that remains?
auto_quant_d = auto_quant.drop(auto_quant.index[10:85])
#results as dataframe
pd.DataFrame({'range':auto_quant_d.max() - auto_quant_d.min(),
              'mean':auto_quant_d.mean(),
              'std':auto_quant_d.std()
             })
# Out:
#                range         mean         std
# mpg             35.6    24.374763    7.872565
# cylinders        5.0     5.381703    1.658135
# displacement   387.0   187.880126  100.169973
# horsepower     184.0   101.003155   36.003208
# weight        3348.0  2938.854890  811.640668
# acceleration    16.3    15.704101    2.719913

# %%
# 9 (e) Using the full data set, investigate the predictors graphically, 
# using scatterplots or other tools of your choice. Create some plots 
# highlighting the relationships among the predictors. Comment on your findings.

# combine numeric quantitive data with original qualitive data
auto_new = pd.concat([auto_quant,auto[datatypes['qual']]],axis=1)
#pairplot grid
pd.plotting.scatter_matrix(auto_new,figsize=[15,15]);
